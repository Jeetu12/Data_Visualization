# %% [markdown]
# ### **1. What is Matplotlib and what are its key features?**
#
# **Theory:**
# Matplotlib is a comprehensive 2D and limited 3D plotting library in Python used for creating static, animated, and interactive visualizations. It’s widely used for scientific and data analysis tasks.
#
# **Key Features:**
#
# * Support for various plot types (line, bar, scatter, histogram, etc.)
# * Customizable plots (titles, axes, legends)
# * Supports LaTeX-style formatting
# * Integrates well with NumPy and pandas
# * Can be used in Python scripts, Jupyter Notebooks, and GUIs
#
# ---
#
# ### **2. How do you create a basic line plot using Matplotlib?**
#
# **Theory:**
# A line plot is useful for visualizing data trends over intervals. You use `plt.plot()` to create one.
#
# **Practical (Python Code):**
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4, 5]
# y = [10, 15, 13, 17, 20]
#
# plt.plot(x, y)
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.title("Basic Line Plot")
# plt.show()
# ```
#
# ---
#
# ### **3. Explain how to customize plot labels, titles, and legends in Matplotlib.**
#
# **Theory:**
# Customizations help in making plots more informative and readable:
#
# * `plt.title()` adds a title
# * `plt.xlabel()` and `plt.ylabel()` label axes
# * `plt.legend()` adds a legend to identify multiple data series
#
# **Practical:**
#
# ```python
# x = [1, 2, 3]
# y1 = [2, 4, 6]
# y2 = [1, 3, 5]
#
# plt.plot(x, y1, label='Line 1')
# plt.plot(x, y2, label='Line 2')
# plt.title("Customized Plot")
# plt.xlabel("X-axis Label")
# plt.ylabel("Y-axis Label")
# plt.legend()
# plt.show()
# ```
#
# ---
#
# ### **4. What are subplots in Matplotlib, and how do you use them to create multiple plots?**
#
# **Theory:**
# Subplots allow displaying multiple plots in one figure using `plt.subplot()` or `plt.subplots()`.
#
# **Practical:**
#
# ```python
# fig, axs = plt.subplots(1, 2)  # 1 row, 2 columns
#
# axs[0].plot([1, 2, 3], [1, 4, 9])
# axs[0].set_title('Plot 1')
#
# axs[1].plot([1, 2, 3], [9, 4, 1])
# axs[1].set_title('Plot 2')
#
# plt.tight_layout()
# plt.show()
# ```
#
# ---
#
# ### **5. What is Seaborn and how does it enhance data visualization in Python?**
#
# **Theory:**
# Seaborn is a high-level Python data visualization library built on top of Matplotlib. It provides a cleaner syntax and better default styles, especially for statistical plots.
#
# **Features:**
#
# * Beautiful default styles
# * Easy plotting of statistical relationships
# * Integrates well with pandas DataFrames
# * Supports complex visualizations like heatmaps, violin plots, pair plots, etc.
#
# ---

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2)  # 1 row, 2 columns

axs[0].plot([1, 2, 3], [1, 4, 9])
axs[0].set_title('Plot 1')

axs[1].plot([1, 2, 3], [9, 4, 1])
axs[1].set_title('Plot 2')

plt.tight_layout()
plt.show()

# %%
x = [1, 2, 3]
y1 = [2, 4, 6]
y2 = [1, 3, 5]

plt.plot(x, y1, label='Line 1')
plt.plot(x, y2, label='Line 2')
plt.title("Customized Plot")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 17, 20]

plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Basic Line Plot")
plt.show()

# %% [markdown]
# ### **6. How do you create a scatter plot with regression line using Seaborn?**
#
# **Theory:**
# Seaborn’s `regplot()` or `lmplot()` can be used to create scatter plots with a linear regression line. It helps in visualizing the relationship and trend between two numerical variables.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Sample data
# tips = sns.load_dataset("tips")
#
# # Scatter plot with regression line
# sns.regplot(x="total_bill", y="tip", data=tips)
# plt.title("Total Bill vs Tip with Regression Line")
# plt.show()
# ```
#
# ---
#
# ### **7. Explain how to use Seaborn’s pairplot() for visualizing relationships between multiple variables.**
#
# **Theory:**
# `pairplot()` visualizes pairwise relationships in a dataset. It creates scatter plots for each numerical feature combination and histograms on the diagonals.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Load dataset
# iris = sns.load_dataset("iris")
#
# # Pairplot
# sns.pairplot(iris, hue="species")
# plt.suptitle("Pairplot of Iris Dataset", y=1.02)
# plt.show()
# ```
#
# ---
#
# ### **8. How can you customize the appearance of plots using Seaborn’s style settings?**
#
# **Theory:**
# Seaborn offers built-in themes to enhance plot aesthetics using `sns.set_style()` and color palettes using `sns.set_palette()`.
#
# **Available Styles:** `'darkgrid'`, `'whitegrid'`, `'dark'`, `'white'`, `'ticks'`
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.set_style("whitegrid")  # Apply white grid style
# sns.set_palette("pastel")   # Set pastel color palette
#
# # Plot example
# tips = sns.load_dataset("tips")
# sns.boxplot(x="day", y="total_bill", data=tips)
# plt.title("Boxplot with Custom Style")
# plt.show()
# ```
#
# ---
#
# ### **9. What is Plotly and what are its advantages for interactive data visualization?**
#
# **Theory:**
# Plotly is a graphing library that enables the creation of interactive and web-based visualizations. It supports a wide range of chart types and is ideal for dashboards.
#
# **Advantages:**
#
# * Interactivity (hover, zoom, pan)
# * Web-friendly outputs (HTML, dashboards)
# * 3D plotting support
# * Integrates with Dash for full web apps
# * Cross-platform usage in Python, R, JavaScript
#
# ---
#
# ### **10. How do you create an interactive bar chart using Plotly?**
#
# **Theory:**
# Use `plotly.express` or `plotly.graph_objects` to create dynamic charts. The output can be viewed directly in notebooks or web apps.
#
# **Practical (using plotly.express):**
#
# ```python
# import plotly.express as px
#
# # Sample data
# data = {"Fruits": ["Apples", "Bananas", "Cherries"], "Quantity": [10, 15, 7]}
# df = px.data.tips()  # You can also use custom DataFrames
#
# # Bar chart
# fig = px.bar(data_frame=data, x="Fruits", y="Quantity", title="Fruit Quantity")
# fig.show()
# ```
#
# ---

# %%
import plotly.express as px

# Sample data
data = {"Fruits": ["Apples", "Bananas", "Cherries"], "Quantity": [10, 15, 7]}
df = px.data.tips()  # You can also use custom DataFrames

# Bar chart
fig = px.bar(data_frame=data, x="Fruits", y="Quantity", title="Fruit Quantity")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")  # Apply white grid style
sns.set_palette("pastel")   # Set pastel color palette

# Plot example
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Boxplot with Custom Style")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
iris = sns.load_dataset("iris")

# Pairplot
sns.pairplot(iris, hue="species")
plt.suptitle("Pairplot of Iris Dataset", y=1.02)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset("tips")

# Scatter plot with regression line
sns.regplot(x="total_bill", y="tip", data=tips)
plt.title("Total Bill vs Tip with Regression Line")
plt.show()

# %% [markdown]
# Here are the **theory** and **practical** answers for Data Visualization Questions **11 to 15**:
#
# ---
#
# ### **11. Explain how to use Plotly’s `go.Figure()` for customizing plots.**
#
# **Theory:**
# `plotly.graph_objects.Figure()` offers full control to build highly customized and interactive visualizations. You can add traces (e.g., `go.Scatter`, `go.Bar`), update layouts, titles, axes, etc.
#
# **Practical:**
#
# ```python
# import plotly.graph_objects as go
#
# # Create a figure
# fig = go.Figure()
#
# # Add a line trace
# fig.add_trace(go.Scatter(x=[1, 2, 3], y=[10, 15, 13], mode='lines+markers', name='Line 1'))
#
# # Customize layout
# fig.update_layout(
#     title='Custom Line Plot',
#     xaxis_title='X Axis',
#     yaxis_title='Y Axis',
#     template='plotly_dark'
# )
#
# fig.show()
# ```
#
# ---
#
# ### **12. Discuss the use of Plotly’s Dash for creating interactive web applications.**
#
# **Theory:**
# Dash is a Python framework built on top of Plotly for building interactive web applications without JavaScript. It’s widely used for analytical dashboards and data apps.
#
# **Key Features:**
#
# * Uses Flask, React.js, and Plotly
# * Interactive callbacks with Python functions
# * Ideal for data dashboards, simulations, reporting tools
#
# **Basic App Example:**
#
# ```python
# # Install Dash first: pip install dash
# import dash
# from dash import html
#
# app = dash.Dash(__name__)
#
# app.layout = html.Div([
#     html.H1("Hello, Dash!"),
#     html.P("This is a basic Dash app.")
# ])
#
# if __name__ == '__main__':
#     app.run_server(debug=True)
# ```
#
# ---
#
# ### **13. When would you use a bar chart instead of a line chart in data analysis?**
#
# **Theory:**
# Use a **bar chart** when:
#
# * You want to compare **categorical data** (e.g., sales by region, items sold by category)
# * The data is **not continuous over time**
#
# Use a **line chart** for **time series** or **trend analysis**.
#
# **Example Use Case:**
#
# * Bar chart: Revenue by product category
# * Line chart: Monthly sales trend over a year
#
# ---
#
# ### **14. What are the best use cases for a scatter plot, and how do you create one in Python?**
#
# **Theory:**
# A **scatter plot** is best used to:
#
# * Visualize the relationship between two numeric variables
# * Detect patterns, clusters, outliers
# * Understand correlation
#
# **Practical:**
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [5, 7, 8, 7, 2, 17]
# y = [99, 86, 87, 88, 100, 86]
#
# plt.scatter(x, y)
# plt.title("Simple Scatter Plot")
# plt.xlabel("X values")
# plt.ylabel("Y values")
# plt.show()
# ```
#
# ---
#
# ### **15. In which scenarios would you use a histogram over a box plot for data visualization?**
#
# **Theory:**
# Use a **histogram** when:
#
# * You want to understand the **distribution** and **frequency** of numerical data
# * You need to see **how often** values occur in intervals (bins)
#
# Use a **box plot** when:
#
# * You want to quickly compare **medians**, **IQR**, and **outliers**
#
# **Histogram Example:**
#
# ```python
# import matplotlib.pyplot as plt
#
# data = [10, 20, 20, 30, 40, 40, 40, 50, 60, 70, 80, 90]
#
# plt.hist(data, bins=5)
# plt.title("Histogram of Values")
# plt.xlabel("Value Range")
# plt.ylabel("Frequency")
# plt.show()
# ```
#
# ---

# %%
import matplotlib.pyplot as plt

data = [10, 20, 20, 30, 40, 40, 40, 50, 60, 70, 80, 90]

plt.hist(data, bins=5)
plt.title("Histogram of Values")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [5, 7, 8, 7, 2, 17]
y = [99, 86, 87, 88, 100, 86]

plt.scatter(x, y)
plt.title("Simple Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Add a line trace
fig.add_trace(go.Scatter(x=[1, 2, 3], y=[10, 15, 13], mode='lines+markers', name='Line 1'))

# Customize layout
fig.update_layout(
    title='Custom Line Plot',
    xaxis_title='X Axis',
    yaxis_title='Y Axis',
    template='plotly_dark'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install dash
import dash
from dash import html

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Hello, Dash!"),
    html.P("This is a basic Dash app.")
])

if __name__ == '__main__':
    app.run(debug=True)

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Hello, Dash!"),
    html.P("This is a basic Dash app.")
])

if __name__ == '__main__':
    app.run(debug=True)

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Hello, Dash!"),
    html.P("This is a basic Dash app.")
])

if __name__ == '__main__':
    app.run(debug=True)

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Hello, Dash!"),
    html.P("This is a basic Dash app.")
])

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ### **16. Explain when to use a pie chart versus a bar chart.**
#
# **Theory:**
#
# * Use a **pie chart** when you want to show **proportions or percentages** of a whole for a **limited number of categories** (usually less than 6).
# * Use a **bar chart** when comparing **absolute values** across **multiple categories**.
#
# **Why prefer bar over pie often?**
# Bar charts are easier to read accurately, especially when categories are numerous or values are similar.
#
# **Practical (Pie Chart Example):**
#
# ```python
# import matplotlib.pyplot as plt
#
# labels = ['A', 'B', 'C']
# sizes = [30, 50, 20]
#
# plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
# plt.title("Pie Chart Example")
# plt.show()
# ```
#
# ---
#
# ### **17. When should you use a heatmap in your data visualizations, and how would you create one using Seaborn?**
#
# **Theory:**
#
# * Use a **heatmap** when you want to visualize the **magnitude of values** in a matrix format (e.g., correlation matrix, pivot tables).
# * It is useful for **pattern recognition**, especially in **correlation matrices**, **confusion matrices**, or **multi-feature comparisons**.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Sample data
# data = pd.DataFrame({
#     'A': [1, 2, 3],
#     'B': [2, 4, 5],
#     'C': [5, 6, 7]
# })
#
# corr = data.corr()
# sns.heatmap(corr, annot=True, cmap='coolwarm')
# plt.title("Correlation Heatmap")
# plt.show()
# ```
#
# ---
#
# ### **18. What are the appropriate use cases for a violin plot? How is it different from a box plot?**
#
# **Theory:**
#
# * A **violin plot** shows both the **distribution** (like a KDE curve) and **summary statistics** (like a box plot).
# * It is ideal when you want to compare **distribution shapes** across categories.
#
# **Difference from Box Plot:**
#
# * Box plot shows quartiles and outliers only.
# * Violin plot shows **density** along with quartiles.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# tips = sns.load_dataset('tips')
#
# sns.violinplot(x='day', y='total_bill', data=tips)
# plt.title("Violin Plot of Total Bill by Day")
# plt.show()
# ```
#
# ---
#
# ### **19. When would you use a pair plot to explore data relationships, and how do you create one in Seaborn?**
#
# **Theory:**
#
# * Use a **pair plot** to visualize **relationships and distributions** between multiple numerical features.
# * It’s best for **exploratory data analysis (EDA)** to check for **correlations**, **clusters**, and **trends**.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# iris = sns.load_dataset('iris')
# sns.pairplot(iris, hue='species')
# plt.suptitle("Pair Plot of Iris Dataset", y=1.02)
# plt.show()
# ```
#
# ---
#
# ### **20. Explain when a stacked bar chart is useful and how you would create it in Matplotlib.**
#
# **Theory:**
#
# * A **stacked bar chart** is used to show the **total value across categories** and the **contribution of each sub-category**.
# * Ideal for comparing **part-to-whole relationships** across different groups.
#
# **Practical:**
#
# ```python
# import matplotlib.pyplot as plt
#
# labels = ['Q1', 'Q2', 'Q3']
# men = [20, 35, 30]
# women = [25, 32, 34]
#
# plt.bar(labels, men, label='Men')
# plt.bar(labels, women, bottom=men, label='Women')
#
# plt.title('Stacked Bar Chart')
# plt.xlabel('Quarter')
# plt.ylabel('Sales')
# plt.legend()
# plt.show()
# ```
#
# ---

# %%
import matplotlib.pyplot as plt

labels = ['Q1', 'Q2', 'Q3']
men = [20, 35, 30]
women = [25, 32, 34]

plt.bar(labels, men, label='Men')
plt.bar(labels, women, bottom=men, label='Women')

plt.title('Stacked Bar Chart')
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species')
plt.suptitle("Pair Plot of Iris Dataset", y=1.02)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

sns.violinplot(x='day', y='total_bill', data=tips)
plt.title("Violin Plot of Total Bill by Day")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [2, 4, 5],
    'C': [5, 6, 7]
})

corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
sizes = [30, 50, 20]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# Here are the **theory** and **practical** answers for Data Visualization Questions **21 to 25**:
#
# ---
#
# ### **21. In what situations would you use a 3D scatter plot in Plotly, and how is it implemented?**
#
# **Theory:**
#
# * Use a **3D scatter plot** when you want to visualize data points across **three continuous dimensions** (e.g., X, Y, Z).
# * It's useful when identifying **clusters, trends, or patterns** in high-dimensional datasets.
#
# **Practical (Plotly):**
#
# ```python
# import plotly.express as px
# import pandas as pd
#
# df = px.data.iris()
# fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length',
#                     color='species', title='3D Scatter Plot - Iris Dataset')
# fig.show()
# ```
#
# ---
#
# ### **22. Why would you use a box plot to visualize data distribution, and how does it compare to a violin plot?**
#
# **Theory:**
#
# * Use a **box plot** to visualize **summary statistics** of a dataset: median, quartiles, and outliers.
# * **Violin plot** gives **distribution shape** in addition to summary stats.
# * Use **box plot** when you want a cleaner, simpler comparison of distributions.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# tips = sns.load_dataset('tips')
# sns.boxplot(x='day', y='total_bill', data=tips)
# plt.title("Box Plot of Total Bill by Day")
# plt.show()
# ```
#
# ---
#
# ### **23. When is it appropriate to use a density plot, and how do you create one in Seaborn?**
#
# **Theory:**
#
# * A **density plot** (KDE plot) is used to estimate the **probability density function** of a continuous variable.
# * It’s appropriate when you want a **smooth curve** showing the distribution (instead of a histogram's bars).
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.kdeplot(data=tips, x='total_bill', shade=True)
# plt.title("Density Plot of Total Bill")
# plt.show()
# ```
#
# ---
#
# ### **24. In which cases would a time series line plot be preferable over a bar chart?**
#
# **Theory:**
#
# * Use a **time series line plot** when you want to analyze **trends over time** (e.g., sales, stock prices, temperature).
# * Line plots show **continuous flow** of data, while bar charts emphasize **discrete comparisons**.
#
# **Practical:**
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Sample time series data
# data = {'Date': pd.date_range(start='2023-01-01', periods=5, freq='D'),
#         'Sales': [100, 120, 130, 110, 140]}
# df = pd.DataFrame(data)
#
# plt.plot(df['Date'], df['Sales'], marker='o')
# plt.title("Time Series Line Plot of Sales")
# plt.xlabel("Date")
# plt.ylabel("Sales")
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ### **25. What are the appropriate scenarios for using a radar (spider) chart, and how would you create one using Plotly?**
#
# **Theory:**
#
# * A **radar (spider) chart** is used to compare **multiple variables** for different categories on a **circular grid**.
# * Best suited for **skill comparison**, **performance metrics**, or **multi-criteria decision making**.
#
# **Practical (Plotly):**
#
# ```python
# import plotly.graph_objects as go
#
# categories = ['Speed', 'Reliability', 'Comfort', 'Safety', 'Efficiency']
# values = [80, 90, 70, 85, 75]
#
# fig = go.Figure(data=go.Scatterpolar(
#     r=values,
#     theta=categories,
#     fill='toself',
#     name='Car A'
# ))
# fig.update_layout(
#     polar=dict(radialaxis=dict(visible=True)),
#     title="Radar Chart Example",
#     showlegend=True
# )
# fig.show()
# ```
#
# ---

# %%
import plotly.graph_objects as go

categories = ['Speed', 'Reliability', 'Comfort', 'Safety', 'Efficiency']
values = [80, 90, 70, 85, 75]

fig = go.Figure(data=go.Scatterpolar(
    r=values,
    theta=categories,
    fill='toself',
    name='Car A'
))
fig.update_layout(
    polar=dict(radialaxis=dict(visible=True)),
    title="Radar Chart Example",
    showlegend=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample time series data
data = {'Date': pd.date_range(start='2023-01-01', periods=5, freq='D'),
        'Sales': [100, 120, 130, 110, 140]}
df = pd.DataFrame(data)

plt.plot(df['Date'], df['Sales'], marker='o')
plt.title("Time Series Line Plot of Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(data=tips, x='total_bill', shade=True)
plt.title("Density Plot of Total Bill")
plt.show()
# Out:
# <ipython-input-26-3cd372372dc6>:4: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title("Box Plot of Total Bill by Day")
plt.show()

# %%
import plotly.express as px
import pandas as pd

df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length',
                    color='species', title='3D Scatter Plot - Iris Dataset')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here are the **theory** and **practical** answers for Data Visualization Questions **26 to 30**:
#
# ---
#
# ### **26. When would you use a waterfall chart, and how would you create one in Python?**
#
# **Theory:**
#
# * A **waterfall chart** is used to show how an initial value is affected by **a series of positive or negative changes**.
# * It’s ideal for **financial analysis** (e.g., profit breakdown, budget vs. actual analysis).
#
# **Practical (Plotly):**
#
# ```python
# import plotly.graph_objects as go
#
# fig = go.Figure(go.Waterfall(
#     name = "20", orientation = "v",
#     measure = ["relative", "relative", "total", "relative", "total"],
#     x = ["Revenue", "Expenses", "Net Profit", "Taxes", "Final Profit"],
#     textposition = "outside",
#     y = [300, -200, 0, -50, 0],
#     connector = {"line":{"color":"rgb(63, 63, 63)"}}
# ))
# fig.update_layout(title = "Waterfall Chart Example")
# fig.show()
# ```
#
# ---
#
# ### **27. Explain when to use a bubble chart and how it helps in visualizing multivariate data.**
#
# **Theory:**
#
# * A **bubble chart** is used to visualize data with **three dimensions**: X, Y, and **bubble size** (often represents a magnitude like population).
# * Ideal for showing **comparisons** and **distribution** with a third variable encoded visually.
#
# **Practical (Plotly):**
#
# ```python
# import plotly.express as px
#
# df = px.data.gapminder().query("year == 2007")
# fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent",
#                  hover_name="country", log_x=True, size_max=60,
#                  title="Bubble Chart - GDP vs Life Expectancy")
# fig.show()
# ```
#
# ---
#
# ### **28. In what situations is a heatmap more useful than a scatter plot for visualizing data?**
#
# **Theory:**
#
# * A **heatmap** is more useful when:
#
#   * You want to **visualize correlations**, **confusion matrices**, or **frequencies** across two variables.
#   * The dataset is **categorical or grouped** rather than continuous points.
#
# **Practical (Seaborn):**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# flights = sns.load_dataset("flights").pivot("month", "year", "passengers")
# sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu")
# plt.title("Heatmap of Monthly Airline Passengers")
# plt.show()
# ```
#
# ---
#
# ### **29. When would you use a histogram to visualize data, and how does it differ from a bar chart?**
#
# **Theory:**
#
# * Use a **histogram** to show the **distribution** of a single continuous variable.
# * It differs from a **bar chart**, which shows **frequency or comparison** between discrete categories.
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.histplot(data=tips, x="total_bill", bins=10, kde=True)
# plt.title("Histogram of Total Bill")
# plt.show()
# ```
#
# ---
#
# ### **30. In what cases would a line plot not be ideal for visualizing changes over time?**
#
# **Theory:**
#
# * A **line plot** is not ideal when:
#
#   * Data is **categorical** or not continuous.
#   * Data has **too much noise**, causing misleading trends.
#   * Better alternatives like **bar charts** or **area charts** may highlight variation better for discrete intervals.
#
# **Alternative Practical Example (Bar Plot):**
#
# ```python
# df = pd.DataFrame({
#     'Month': ['Jan', 'Feb', 'Mar', 'Apr'],
#     'Sales': [200, 220, 180, 210]
# })
# plt.bar(df['Month'], df['Sales'])
# plt.title("Bar Chart Instead of Line Plot")
# plt.xlabel("Month")
# plt.ylabel("Sales")
# plt.show()
# ```
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar', 'Apr'],
    'Sales': [200, 220, 180, 210]
})
plt.bar(df['Month'], df['Sales'])
plt.title("Bar Chart Instead of Line Plot")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the 'tips' dataset
tips = sns.load_dataset('tips')

sns.histplot(data=tips, x="total_bill", bins=10, kde=True)
plt.title("Histogram of Total Bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset("flights").pivot(index="month", columns="year", values="passengers") # Changed to keyword arguments
sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu")
plt.title("Heatmap of Monthly Airline Passengers")
plt.show()

# %%
import plotly.express as px

df = px.data.gapminder().query("year == 2007")
fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60,
                 title="Bubble Chart - GDP vs Life Expectancy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Waterfall(
    name = "20", orientation = "v",
    measure = ["relative", "relative", "total", "relative", "total"],
    x = ["Revenue", "Expenses", "Net Profit", "Taxes", "Final Profit"],
    textposition = "outside",
    y = [300, -200, 0, -50, 0],
    connector = {"line":{"color":"rgb(63, 63, 63)"}}
))
fig.update_layout(title = "Waterfall Chart Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here are the **theory** and **practical** answers for the final Data Visualization Questions **31 and 32**:
#
# ---
#
# ### **31. When is a treemap visualization useful, and how do you implement it in Plotly?**
#
# **Theory:**
#
# * A **treemap** is useful for:
#
#   * Showing **hierarchical data**.
#   * Comparing proportions between categories and sub-categories.
#   * Understanding **part-to-whole** relationships visually through nested rectangles.
#
# * Ideal when analyzing **market share, product categories, or organizational structures**.
#
# **Practical (Plotly):**
#
# ```python
# import plotly.express as px
#
# df = px.data.tips()
# fig = px.treemap(df, path=['day', 'time'], values='total_bill',
#                  title='Treemap of Total Bill by Day and Time')
# fig.show()
# ```
#
# ---
#
# ### **32. What is the purpose of Seaborn's `sns.set_style()` method, and how do you apply different plot styles?**
#
# **Theory:**
#
# * `sns.set_style()` is used to control the **overall aesthetic theme** of Seaborn plots.
# * It helps make plots more readable and professional.
# * Available styles:
#
#   * `"darkgrid"` (default, great for regression)
#   * `"whitegrid"` (good for plots with categorical data)
#   * `"dark"`
#   * `"white"`
#   * `"ticks"`
#
# **Practical:**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.set_style("whitegrid")  # Choose from: "darkgrid", "whitegrid", "dark", "white", "ticks"
# tips = sns.load_dataset("tips")
# sns.boxplot(x="day", y="total_bill", data=tips)
# plt.title("Boxplot with Seaborn Style")
# plt.show()
# ```
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")  # Choose from: "darkgrid", "whitegrid", "dark", "white", "ticks"
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Boxplot with Seaborn Style")
plt.show()

# %%
import plotly.express as px

df = px.data.tips()
fig = px.treemap(df, path=['day', 'time'], values='total_bill',
                 title='Treemap of Total Bill by Day and Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
